# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key
#api_key = "3bddfc8bf688bca80334bf98d33570cb"
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
country_code = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    #for the heck of it we will also collect the country code. God forbid there are 2 cities with similar names!!!
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        country_code.append(country)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %%
print(f"We collected {len(cities)} individual cities and their corresponding {len(country_code)} countries")
# Out:
# We collected 598 individual cities and their corresponding 598 countries

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
#lets save more variables than we need to!
lat = []
lon=[]
citylist = []
temp=[]
tempmax= []
tempmin = []
clouds= []
dt=[]
wind = []
humidity=[]
#counters for record processing. Dont want to exceed 60 per minute!
counter = 1
max60requests_counter = 1
# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# Loop through the list of cities and perform a request for data on each
print("Beginning DATA RETRIVAL")
print("-----------------------")

for city in cities:
    
    try:        
        response = requests.get(query_url + city).json()
        print(f" Processing record number {counter} of set {max60requests_counter} | {(response['name'])}")
        print(f"{(query_url + city)}")
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])           
        citylist.append(response['name'])
        temp.append(response['main']['temp'])
        tempmax.append(response['main']['temp_max'])
        tempmin.append(response['main']['temp_min'])
        humidity.append(response['main']['humidity'])
        wind.append(response['wind']['speed'])
        dt.append(response['dt'])
        clouds.append(response['clouds']['all'])
        if counter < 60:
            counter +=1
        else:
            counter = 0
            max60requests_counter +=1
            time.sleep(60)
            

            
            
    except KeyError:
        print("Record not found. skipping and moving on up!")
print("-----------------------")
print("Retrival Complete")
print("-----------------------")
# Out:
# Beginning DATA RETRIVAL
# -----------------------
#  Processing record number 1 of set 1 | Severo-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=severo-kurilsk
#  Processing record number 2 of set 1 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=hithadhoo
#  Processing record number 3 of set 1 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=ushuaia
#  Processing record number 4 of set 1 | Kuytun
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=kuytun
#  Processing record number 5 of set 1 | Mataura
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=mataura
#  Processing record number 6 of set 1 | Hilo
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=hilo
#  Processing record number 7 of set 1 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=rikitea
# Record not found. skipping and moving on up!
#  Processing record number 8 of set 1 | Atuona
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=atuona
# Record not found. skipping and moving on up!
#  Processing record number 9 of set 1 | Albany
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=albany
#  Processing record number 10 of set 1 | Show Low
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=show low
#  Processing record number 11 of set 1 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=upernavik
#  Processing record number 12 of set 1 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=hermanus
#  Processing record number 13 of set 1 | Busselton
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=busselton
#  Processing record number 14 of set 1 | Marienburg
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=marienburg
# Record not found. skipping and moving on up!
#  Processing record number 15 of set 1 | Canyon
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=canyon
#  Processing record number 16 of set 1 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=bredasdorp
# Record not found. skipping and moving on up!
#  Processing record number 17 of set 1 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=ilulissat
#  Processing record number 18 of set 1 | Quelimane
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=quelimane
#  Processing record number 19 of set 1 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=tasiilaq
#  Processing record number 20 of set 1 | Bluff
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=bluff
#  Processing record number 21 of set 1 | Fernley
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=fernley
#  Processing record number 22 of set 1 | Konya
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=konya
#  Processing record number 23 of set 1 | Venice
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=venice
# Record not found. skipping and moving on up!
#  Processing record number 24 of set 1 | Avarua
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=avarua
#  Processing record number 25 of set 1 | East London
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=east london
#  Processing record number 26 of set 1 | Tete
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=tete
#  Processing record number 27 of set 1 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=aklavik
#  Processing record number 28 of set 1 | Hobart
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=hobart
#  Processing record number 29 of set 1 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=nikolskoye
#  Processing record number 30 of set 1 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=port alfred
# Record not found. skipping and moving on up!
#  Processing record number 31 of set 1 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=iqaluit
#  Processing record number 32 of set 1 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=mahebourg
#  Processing record number 33 of set 1 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=punta arenas
#  Processing record number 34 of set 1 | Constitucion
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=constitucion
#  Processing record number 35 of set 1 | Nocupetaro
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=nocupetaro
#  Processing record number 36 of set 1 | Vaini
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=vaini
#  Processing record number 37 of set 1 | Minab
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=minab
#  Processing record number 38 of set 1 | Tuatapere
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=tuatapere
#  Processing record number 39 of set 1 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=arraial do cabo
#  Processing record number 40 of set 1 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=new norfolk
#  Processing record number 41 of set 1 | Bathsheba
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=bathsheba
#  Processing record number 42 of set 1 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=norman wells
#  Processing record number 43 of set 1 | Brae
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=brae
# Record not found. skipping and moving on up!
#  Processing record number 44 of set 1 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=coquimbo
# Record not found. skipping and moving on up!
#  Processing record number 45 of set 1 | Kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=kudahuvadhoo
#  Processing record number 46 of set 1 | Vondrozo
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=vondrozo
#  Processing record number 47 of set 1 | Flinders
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=flinders
#  Processing record number 48 of set 1 | Thompson
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=thompson
#  Processing record number 49 of set 1 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=nanortalik
#  Processing record number 50 of set 1 | Umm Bab
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=umm bab
#  Processing record number 51 of set 1 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=yellowknife
#  Processing record number 52 of set 1 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=narsaq
#  Processing record number 53 of set 1 | Tres Arroyos
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=tres arroyos
#  Processing record number 54 of set 1 | Yima
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=yima
#  Processing record number 55 of set 1 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=clyde river
#  Processing record number 56 of set 1 | Caravelas
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=caravelas
#  Processing record number 57 of set 1 | Iquique
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=iquique
# Record not found. skipping and moving on up!
#  Processing record number 58 of set 1 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=georgetown
#  Processing record number 59 of set 1 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=jamestown
#  Processing record number 60 of set 1 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=cape town
#  Processing record number 0 of set 2 | Luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=luderitz
#  Processing record number 1 of set 2 | Poum
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=poum
#  Processing record number 2 of set 2 | Talnakh
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=talnakh
#  Processing record number 3 of set 2 | Dikson
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=dikson
#  Processing record number 4 of set 2 | Redmond
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=redmond
#  Processing record number 5 of set 2 | Limbang
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=limbang
#  Processing record number 6 of set 2 | Mount Isa
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=mount isa
#  Processing record number 7 of set 2 | Ahipara
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=ahipara
#  Processing record number 8 of set 2 | Merrill
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=merrill
#  Processing record number 9 of set 2 | Wad Rawah
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=wad rawah
#  Processing record number 10 of set 2 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=kapaa
#  Processing record number 11 of set 2 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=ponta do sol
#  Processing record number 12 of set 2 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=longyearbyen
#  Processing record number 13 of set 2 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=cidreira
#  Processing record number 14 of set 2 | Porto Belo
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=porto belo
#  Processing record number 15 of set 2 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=qaanaaq
#  Processing record number 16 of set 2 | Castro
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=castro
#  Processing record number 17 of set 2 | Batie
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=batie
#  Processing record number 18 of set 2 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=kodiak
# Record not found. skipping and moving on up!
#  Processing record number 19 of set 2 | Madridejos
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=madridejos
#  Processing record number 20 of set 2 | Hobyo
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=hobyo
#  Processing record number 21 of set 2 | Hokitika
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=hokitika
#  Processing record number 22 of set 2 | La Asuncion
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=la asuncion
#  Processing record number 23 of set 2 | Fomboni
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=fomboni
# Record not found. skipping and moving on up!
#  Processing record number 24 of set 2 | Kalianget
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=kalianget
#  Processing record number 25 of set 2 | Zonguldak
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=zonguldak
# Record not found. skipping and moving on up!
#  Processing record number 26 of set 2 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=kavieng
#  Processing record number 27 of set 2 | Hamilton
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=hamilton
#  Processing record number 28 of set 2 | Souillac
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=souillac
#  Processing record number 29 of set 2 | Tarragona
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=tarragona
#  Processing record number 30 of set 2 | Pokhara
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=pokhara
#  Processing record number 31 of set 2 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=cherskiy
#  Processing record number 32 of set 2 | Damghan
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=damghan
#  Processing record number 33 of set 2 | Astoria
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=astoria
#  Processing record number 34 of set 2 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=fortuna
#  Processing record number 35 of set 2 | Klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=klaksvik
# Record not found. skipping and moving on up!
#  Processing record number 36 of set 2 | Airai
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=airai
#  Processing record number 37 of set 2 | Barrow
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=barrow
#  Processing record number 38 of set 2 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=bambous virieux
#  Processing record number 39 of set 2 | Bonthe
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=bonthe
#  Processing record number 40 of set 2 | Stephenville
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=stephenville
#  Processing record number 41 of set 2 | Smithers
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=smithers
#  Processing record number 42 of set 2 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=mar del plata
#  Processing record number 43 of set 2 | Nelson Bay
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=nelson bay
#  Processing record number 44 of set 2 | Banjar
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=banjar
#  Processing record number 45 of set 2 | Bethel
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=bethel
# Record not found. skipping and moving on up!
#  Processing record number 46 of set 2 | Tautira
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=tautira
#  Processing record number 47 of set 2 | Mezhdurechenskiy
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=mezhdurechenskiy
#  Processing record number 48 of set 2 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=butaritari
#  Processing record number 49 of set 2 | Aksarka
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=aksarka
#  Processing record number 50 of set 2 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=provideniya
#  Processing record number 51 of set 2 | Samarai
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=samarai
#  Processing record number 52 of set 2 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=cabo san lucas
#  Processing record number 53 of set 2 | Lensk
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=lensk
#  Processing record number 54 of set 2 | Salalah
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=salalah
#  Processing record number 55 of set 2 | Hofn
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=hofn
#  Processing record number 56 of set 2 | Greenfield
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=greenfield
#  Processing record number 57 of set 2 | Alenquer
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=alenquer
#  Processing record number 58 of set 2 | Kimbe
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=kimbe
#  Processing record number 59 of set 2 | Nabire
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=nabire
#  Processing record number 60 of set 2 | Bandundu
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=bandundu
# Record not found. skipping and moving on up!
#  Processing record number 0 of set 3 | Chartres
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=chartres
#  Processing record number 1 of set 3 | Pitogo
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=pitogo
#  Processing record number 2 of set 3 | Chuy
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=chuy
#  Processing record number 3 of set 3 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=port elizabeth
#  Processing record number 4 of set 3 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=kaitangata
#  Processing record number 5 of set 3 | Kalevala
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=kalevala
# Record not found. skipping and moving on up!
#  Processing record number 6 of set 3 | Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=sao filipe
#  Processing record number 7 of set 3 | Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=port lincoln
#  Processing record number 8 of set 3 | Balabac
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=balabac
#  Processing record number 9 of set 3 | Houma
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=houma
# Record not found. skipping and moving on up!
#  Processing record number 10 of set 3 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=ribeira grande
#  Processing record number 11 of set 3 | Port Blair
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=port blair
#  Processing record number 12 of set 3 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=kavaratti
#  Processing record number 13 of set 3 | Yakuplu
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=yakuplu
#  Processing record number 14 of set 3 | Nizwa
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=nizwa
#  Processing record number 15 of set 3 | Harsin
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=harsin
#  Processing record number 16 of set 3 | Ruteng
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=ruteng
#  Processing record number 17 of set 3 | Ancud
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=ancud
#  Processing record number 18 of set 3 | Mehamn
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=mehamn
#  Processing record number 19 of set 3 | Chernyshevskiy
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=chernyshevskiy
#  Processing record number 20 of set 3 | Carauari
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=carauari
# Record not found. skipping and moving on up!
#  Processing record number 21 of set 3 | Nemuro
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=nemuro
#  Processing record number 22 of set 3 | Trairi
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=trairi
#  Processing record number 23 of set 3 | Lebu
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=lebu
#  Processing record number 24 of set 3 | Saint Anthony
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=saint anthony
#  Processing record number 25 of set 3 | Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=kruisfontein
#  Processing record number 26 of set 3 | Srivardhan
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=srivardhan
# Record not found. skipping and moving on up!
#  Processing record number 27 of set 3 | Lata
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=lata
#  Processing record number 28 of set 3 | Agutaya
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=agutaya
#  Processing record number 29 of set 3 | Vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=vestmannaeyjar
#  Processing record number 30 of set 3 | San Pedro
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=san pedro
#  Processing record number 31 of set 3 | Kasongo-Lunda
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=kasongo-lunda
#  Processing record number 32 of set 3 | Goya
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=goya
#  Processing record number 33 of set 3 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=katsuura
#  Processing record number 34 of set 3 | Lavrentiya
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=lavrentiya
#  Processing record number 35 of set 3 | Hutchinson
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=hutchinson
#  Processing record number 36 of set 3 | Baghdad
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=baghdad
# Record not found. skipping and moving on up!
#  Processing record number 37 of set 3 | Ulaangom
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=ulaangom
#  Processing record number 38 of set 3 | Angoche
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=angoche
#  Processing record number 39 of set 3 | Elizabeth City
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=elizabeth city
#  Processing record number 40 of set 3 | Vicksburg
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=vicksburg
#  Processing record number 41 of set 3 | Dubbo
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=dubbo
#  Processing record number 42 of set 3 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=saldanha
#  Processing record number 43 of set 3 | Baruun-Urt
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=baruun-urt
#  Processing record number 44 of set 3 | Sitka
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=sitka
#  Processing record number 45 of set 3 | Montecristo
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=montecristo
# Record not found. skipping and moving on up!
#  Processing record number 46 of set 3 | Sistranda
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=sistranda
# Record not found. skipping and moving on up!
#  Processing record number 47 of set 3 | Vidim
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=vidim
#  Processing record number 48 of set 3 | Vanavara
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=vanavara
#  Processing record number 49 of set 3 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=chokurdakh
#  Processing record number 50 of set 3 | Cardston
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=cardston
# Record not found. skipping and moving on up!
#  Processing record number 51 of set 3 | Torbay
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=torbay
#  Processing record number 52 of set 3 | Petrolia
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=petrolia
# Record not found. skipping and moving on up!
#  Processing record number 53 of set 3 | Mangrol
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=mangrol
#  Processing record number 54 of set 3 | Maralal
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=maralal
#  Processing record number 55 of set 3 | Halifax
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=halifax
#  Processing record number 56 of set 3 | Port Hardy
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=port hardy
#  Processing record number 57 of set 3 | Grand Island
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=grand island
#  Processing record number 58 of set 3 | Skegness
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=skegness
#  Processing record number 59 of set 3 | Namibe
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=namibe
#  Processing record number 60 of set 3 | Lasa
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=lasa
#  Processing record number 0 of set 4 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=saint-philippe
#  Processing record number 1 of set 4 | Nicoya
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=nicoya
#  Processing record number 2 of set 4 | Codrington
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=codrington
#  Processing record number 3 of set 4 | Mizan Teferi
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=mizan teferi
#  Processing record number 4 of set 4 | Te Anau
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=te anau
#  Processing record number 5 of set 4 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=tuktoyaktuk
# Record not found. skipping and moving on up!
# Record not found. skipping and moving on up!
#  Processing record number 6 of set 4 | Curup
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=curup
#  Processing record number 7 of set 4 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=saskylakh
#  Processing record number 8 of set 4 | Pozo Colorado
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=pozo colorado
#  Processing record number 9 of set 4 | Abaza
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=abaza
#  Processing record number 10 of set 4 | Dire
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=dire
#  Processing record number 11 of set 4 | Uhingen
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=uhingen
#  Processing record number 12 of set 4 | Tabas
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=tabas
#  Processing record number 13 of set 4 | Timbuktu
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=tombouctou
#  Processing record number 14 of set 4 | Havoysund
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=havoysund
# Record not found. skipping and moving on up!
#  Processing record number 15 of set 4 | Gwadar
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=gwadar
#  Processing record number 16 of set 4 | Puerto Ayacucho
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=puerto ayacucho
#  Processing record number 17 of set 4 | Mount Gambier
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=mount gambier
#  Processing record number 18 of set 4 | Beira
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=beira
#  Processing record number 19 of set 4 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=puerto ayora
# Record not found. skipping and moving on up!
#  Processing record number 20 of set 4 | Alice Springs
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=alice springs
#  Processing record number 21 of set 4 | Isangel
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=isangel
#  Processing record number 22 of set 4 | Kwinana
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=kwinana
#  Processing record number 23 of set 4 | Zhicheng
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=zhicheng
#  Processing record number 24 of set 4 | Mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=mitsamiouli
#  Processing record number 25 of set 4 | Nebbi
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=nebbi
#  Processing record number 26 of set 4 | Saint-Francois
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=saint-francois
#  Processing record number 27 of set 4 | Nishihara
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=nishihara
# Record not found. skipping and moving on up!
#  Processing record number 28 of set 4 | Carballo
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=carballo
#  Processing record number 29 of set 4 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=khatanga
#  Processing record number 30 of set 4 | Puerto Leguizamo
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=puerto leguizamo
#  Processing record number 31 of set 4 | Riyadh
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=riyadh
#  Processing record number 32 of set 4 | Jumilla
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=jumilla
#  Processing record number 33 of set 4 | Korba
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=korba
#  Processing record number 34 of set 4 | Qinhuangdao
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=qinhuangdao
#  Processing record number 35 of set 4 | Srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=srednekolymsk
#  Processing record number 36 of set 4 | Victoria
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=victoria
#  Processing record number 37 of set 4 | Sioux Lookout
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=sioux lookout
#  Processing record number 38 of set 4 | Quatre Cocos
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=quatre cocos
#  Processing record number 39 of set 4 | Crixas
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=crixas
#  Processing record number 40 of set 4 | Kuusamo
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=kuusamo
#  Processing record number 41 of set 4 | Hualmay
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=hualmay
#  Processing record number 42 of set 4 | Miraflores
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=miraflores
#  Processing record number 43 of set 4 | Inhambane
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=inhambane
#  Processing record number 44 of set 4 | Vanimo
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=vanimo
#  Processing record number 45 of set 4 | Vila Franca do Campo
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=vila franca do campo
#  Processing record number 46 of set 4 | Laguna
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=laguna
#  Processing record number 47 of set 4 | Guadalupe
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=guadalupe
# Record not found. skipping and moving on up!
#  Processing record number 48 of set 4 | Douglas
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=douglas
#  Processing record number 49 of set 4 | Gat
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=gat
#  Processing record number 50 of set 4 | Bereda
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=bereda
#  Processing record number 51 of set 4 | Shache
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=shache
#  Processing record number 52 of set 4 | Cayenne
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=cayenne
#  Processing record number 53 of set 4 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=carnarvon
#  Processing record number 54 of set 4 | Tazovskiy
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=tazovskiy
#  Processing record number 55 of set 4 | San Cristobal
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=san cristobal
#  Processing record number 56 of set 4 | Alto Araguaia
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=alto araguaia
# Record not found. skipping and moving on up!
#  Processing record number 57 of set 4 | Mackay
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=mackay
# Record not found. skipping and moving on up!
#  Processing record number 58 of set 4 | Sabzevar
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=sabzevar
#  Processing record number 59 of set 4 | Birin
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=birin
#  Processing record number 60 of set 4 | Boone
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=boone
# Record not found. skipping and moving on up!
#  Processing record number 0 of set 5 | Batagay
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=batagay
# Record not found. skipping and moving on up!
#  Processing record number 1 of set 5 | Noumea
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=noumea
#  Processing record number 2 of set 5 | Armacao de Pera
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=armacao de pera
# Record not found. skipping and moving on up!
#  Processing record number 3 of set 5 | Nantucket
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=nantucket
#  Processing record number 4 of set 5 | Kargasok
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=kargasok
#  Processing record number 5 of set 5 | Gizo
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=gizo
#  Processing record number 6 of set 5 | Bontang
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=bontang
#  Processing record number 7 of set 5 | Seminole
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=seminole
#  Processing record number 8 of set 5 | Foz
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=foz
#  Processing record number 9 of set 5 | Richards Bay
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=richards bay
#  Processing record number 10 of set 5 | Codajas
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=codajas
#  Processing record number 11 of set 5 | Tilichiki
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=tilichiki
#  Processing record number 12 of set 5 | Jaisalmer
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=jaisalmer
# Record not found. skipping and moving on up!
#  Processing record number 13 of set 5 | Okhotsk
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=okhotsk
#  Processing record number 14 of set 5 | Prabumulih
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=prabumulih
#  Processing record number 15 of set 5 | Baijiantan
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=baijiantan
#  Processing record number 16 of set 5 | Port Shepstone
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=port shepstone
#  Processing record number 17 of set 5 | Katherine
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=katherine
#  Processing record number 18 of set 5 | Oranjemund
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=oranjemund
#  Processing record number 19 of set 5 | Tecoanapa
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=tecoanapa
#  Processing record number 20 of set 5 | Haines Junction
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=haines junction
#  Processing record number 21 of set 5 | Maniitsoq
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=maniitsoq
#  Processing record number 22 of set 5 | Guarapari
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=guarapari
#  Processing record number 23 of set 5 | Goderich
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=goderich
#  Processing record number 24 of set 5 | Marsa Matruh
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=marsa matruh
#  Processing record number 25 of set 5 | Hirara
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=hirara
#  Processing record number 26 of set 5 | Coihaique
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=coihaique
# Record not found. skipping and moving on up!
#  Processing record number 27 of set 5 | Setermoen
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=setermoen
#  Processing record number 28 of set 5 | Leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=leshukonskoye
#  Processing record number 29 of set 5 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=san patricio
#  Processing record number 30 of set 5 | Liverpool
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=liverpool
#  Processing record number 31 of set 5 | Malumfashi
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=malumfashi
#  Processing record number 32 of set 5 | Basco
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=basco
#  Processing record number 33 of set 5 | Inongo
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=inongo
#  Processing record number 34 of set 5 | Alyangula
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=alyangula
# Record not found. skipping and moving on up!
#  Processing record number 35 of set 5 | Rassvet
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=rassvet
#  Processing record number 36 of set 5 | Wanning
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=wanning
#  Processing record number 37 of set 5 | Camalu
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=camalu
#  Processing record number 38 of set 5 | Cockburn Town
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=cockburn town
#  Processing record number 39 of set 5 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=tiksi
#  Processing record number 40 of set 5 | Baker City
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=baker city
#  Processing record number 41 of set 5 | Taoudenni
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=taoudenni
#  Processing record number 42 of set 5 | Rigaud
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=rigaud
#  Processing record number 43 of set 5 | Makokou
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=makokou
#  Processing record number 44 of set 5 | Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=leningradskiy
#  Processing record number 45 of set 5 | Loiza
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=loiza
#  Processing record number 46 of set 5 | Peniche
# ...
#  Processing record number 8 of set 8 | Tahe
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=tahe
#  Processing record number 9 of set 8 | Kutum
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=kutum
#  Processing record number 10 of set 8 | Allapalli
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=allapalli
#  Processing record number 11 of set 8 | Ballina
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=ballina
#  Processing record number 12 of set 8 | Cururupu
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=cururupu
#  Processing record number 13 of set 8 | Benghazi
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=benghazi
#  Processing record number 14 of set 8 | Pacific Grove
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=pacific grove
#  Processing record number 15 of set 8 | Nador
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=nador
#  Processing record number 16 of set 8 | Zaltan
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=zaltan
#  Processing record number 17 of set 8 | Khuzdar
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=khuzdar
#  Processing record number 18 of set 8 | Margate
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=margate
#  Processing record number 19 of set 8 | Nouadhibou
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=nouadhibou
#  Processing record number 20 of set 8 | Gigmoto
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=gigmoto
#  Processing record number 21 of set 8 | Piran
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=piran
#  Processing record number 22 of set 8 | Plougastel-Daoulas
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=plougastel-daoulas
#  Processing record number 23 of set 8 | Kulu
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=kulu
#  Processing record number 24 of set 8 | Beringovskiy
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=beringovskiy
#  Processing record number 25 of set 8 | Tias
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=tias
#  Processing record number 26 of set 8 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=hasaki
#  Processing record number 27 of set 8 | Morondava
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=morondava
#  Processing record number 28 of set 8 | Constantine
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=constantine
#  Processing record number 29 of set 8 | Atmakur
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=atmakur
#  Processing record number 30 of set 8 | Harper
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=harper
#  Processing record number 31 of set 8 | Kaoma
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=kaoma
#  Processing record number 32 of set 8 | Gloucester
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=gloucester
#  Processing record number 33 of set 8 | Saint George
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=saint george
#  Processing record number 34 of set 8 | Ketchikan
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=ketchikan
#  Processing record number 35 of set 8 | Broome
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=broome
#  Processing record number 36 of set 8 | Pueblo Nuevo
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=pueblo nuevo
#  Processing record number 37 of set 8 | Kunya
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=kunya
#  Processing record number 38 of set 8 | Itanhaem
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=itanhaem
#  Processing record number 39 of set 8 | Kununurra
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=kununurra
#  Processing record number 40 of set 8 | Pichayevo
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=pichayevo
#  Processing record number 41 of set 8 | Sechura
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=sechura
#  Processing record number 42 of set 8 | Maloy
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=maloy
#  Processing record number 43 of set 8 | Williston
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=williston
#  Processing record number 44 of set 8 | Bartica
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=bartica
# Record not found. skipping and moving on up!
#  Processing record number 45 of set 8 | Kichera
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=kichera
# Record not found. skipping and moving on up!
#  Processing record number 46 of set 8 | Botou
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=botou
# Record not found. skipping and moving on up!
# Record not found. skipping and moving on up!
#  Processing record number 47 of set 8 | Kollegal
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=kollegal
#  Processing record number 48 of set 8 | Fenelon Falls
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=fenelon falls
#  Processing record number 49 of set 8 | Moron
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=moron
# Record not found. skipping and moving on up!
#  Processing record number 50 of set 8 | Nogliki
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=nogliki
#  Processing record number 51 of set 8 | Coahuayana
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=coahuayana
#  Processing record number 52 of set 8 | Jiaozuo
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=jiaozuo
#  Processing record number 53 of set 8 | Oparino
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=oparino
#  Processing record number 54 of set 8 | San Quintin
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=san quintin
#  Processing record number 55 of set 8 | Tura
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=tura
#  Processing record number 56 of set 8 | Otjiwarongo
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=otjiwarongo
#  Processing record number 57 of set 8 | Libreville
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=libreville
#  Processing record number 58 of set 8 | Glens Falls
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=glens falls
# Record not found. skipping and moving on up!
#  Processing record number 59 of set 8 | Waddan
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=waddan
#  Processing record number 60 of set 8 | Jalu
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=jalu
#  Processing record number 0 of set 9 | Lac du Bonnet
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=lac du bonnet
# Record not found. skipping and moving on up!
#  Processing record number 1 of set 9 | Goure
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=goure
# Record not found. skipping and moving on up!
#  Processing record number 2 of set 9 | Lazaro Cardenas
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=lazaro cardenas
#  Processing record number 3 of set 9 | Dakar
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=dakar
# Record not found. skipping and moving on up!
#  Processing record number 4 of set 9 | Narsimhapur
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=narsimhapur
#  Processing record number 5 of set 9 | Avera
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=avera
#  Processing record number 6 of set 9 | Mogzon
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=mogzon
#  Processing record number 7 of set 9 | Kuryk
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=kuryk
#  Processing record number 8 of set 9 | Morant Bay
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=morant bay
#  Processing record number 9 of set 9 | Tynda
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=tynda
#  Processing record number 10 of set 9 | Southbridge
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=southbridge
#  Processing record number 11 of set 9 | Vila Velha
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=vila velha
#  Processing record number 12 of set 9 | Belmopan
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=belmopan
#  Processing record number 13 of set 9 | Wang Noi
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=wang noi
#  Processing record number 14 of set 9 | Vao
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=vao
#  Processing record number 15 of set 9 | Merauke
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=merauke
#  Processing record number 16 of set 9 | Lodja
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=lodja
#  Processing record number 17 of set 9 | Vardo
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=vardo
#  Processing record number 18 of set 9 | Sexsmith
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=sexsmith
#  Processing record number 19 of set 9 | Svetlogorsk
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=svetlogorsk
#  Processing record number 20 of set 9 | Agua Buena
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=agua buena
# Record not found. skipping and moving on up!
#  Processing record number 21 of set 9 | Partizanskoye
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=partizanskoye
#  Processing record number 22 of set 9 | Slave Lake
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=slave lake
#  Processing record number 23 of set 9 | Soloneshnoye
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=soloneshnoye
#  Processing record number 24 of set 9 | Tingo Maria
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=tingo maria
#  Processing record number 25 of set 9 | Aleksandrov Gay
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=aleksandrov gay
# Record not found. skipping and moving on up!
#  Processing record number 26 of set 9 | Nechi
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=nechi
#  Processing record number 27 of set 9 | Arvika
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=arvika
#  Processing record number 28 of set 9 | Lerwick
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=lerwick
#  Processing record number 29 of set 9 | Hay River
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=hay river
#  Processing record number 30 of set 9 | Moindou
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=moindou
#  Processing record number 31 of set 9 | Muzhi
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=muzhi
# Record not found. skipping and moving on up!
#  Processing record number 32 of set 9 | Novyy Urengoy
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=novyy urengoy
#  Processing record number 33 of set 9 | Nenjiang
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=nenjiang
#  Processing record number 34 of set 9 | Lebedinyy
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=lebedinyy
#  Processing record number 35 of set 9 | Guanica
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=guanica
#  Processing record number 36 of set 9 | Tabuk
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=tabuk
#  Processing record number 37 of set 9 | Pasni
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=pasni
#  Processing record number 38 of set 9 | Gravdal
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=gravdal
#  Processing record number 39 of set 9 | Gondanglegi
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=gondanglegi
#  Processing record number 40 of set 9 | Tucurui
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=tucurui
#  Processing record number 41 of set 9 | Yatou
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=yatou
#  Processing record number 42 of set 9 | Hakodate
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=hakodate
#  Processing record number 43 of set 9 | Ust-Nera
# http://api.openweathermap.org/data/2.5/weather?appid=32b68acac5b84477b26d1b768501a1ee&units=metric&q=ust-nera

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_list = pd.DataFrame(citylist, columns=['City'])
temp_list = pd.DataFrame(temp, columns=['Temperature'])
humidity_list = pd.DataFrame(humidity, columns=['Humidity'])
clouds_list = pd.DataFrame(clouds, columns=['Clouds'])
wind_speed_list = pd.DataFrame(wind, columns=['Wind'])
lat_list = pd.DataFrame(lat, columns=['Latitude'])
lng_list = pd.DataFrame(lon, columns=['Longitude'])
#combine all into one dataframe and Write to CSV
weather_combined = pd.concat([cities_list, temp_list,humidity_list,clouds_list,wind_speed_list, lng_list, lat_list], axis=1, join_axes=[cities_list.index])
#write to CSV
weather_combined.to_csv('Weather Full Data Frame.csv')
#display 
weather_combined.head(10)
# Out:
#              City  Temperature  Humidity  Clouds   Wind  Longitude  Latitude
# 0  Severo-Kurilsk        -3.15       100      44  11.32     156.12     50.68
# 1       Hithadhoo        28.96       100      88   1.17      73.08     -0.60
# 2         Ushuaia         9.00        70      40   5.10     -68.31    -54.81
# 3          Kuytun        -3.45        72      68   1.57     101.51     54.34
# 4         Mataura        17.78        82       0   2.68     168.86    -46.19
# 5            Hilo        20.75        60      90   3.60    -155.08     19.71
# 6         Rikitea        25.36       100       0   9.67    -134.97    -23.12
# 7          Atuona        28.11        99      44   7.22    -139.03     -9.80
# 8          Albany        -2.86        58      75   0.97     -73.75     42.65
# 9        Show Low         8.88        49       1   2.60    -110.03     34.25

# %%
#describe the dataframe
weather_combined.count()
# Out:
# City           531
# Temperature    531
# Humidity       531
# Clouds         531
# Wind           531
# Longitude      531
# Latitude       531
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_combined['Latitude'], weather_combined['Temperature'])
plt.grid(b=None, which='major', axis='both')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_combined['Latitude'], weather_combined['Humidity'])
plt.grid(b=None, which='major', axis='both')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_combined['Latitude'], weather_combined['Clouds'])
plt.grid(b=None, which='major', axis='both')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_combined['Latitude'], weather_combined['Wind'])
plt.grid(b=None, which='major', axis='both')
